# %%
import pandas as pd
df = pd.read_parquet('cic-collection.parquet')
# Out:
# ---------------------------------------------------------------------------
# ArrowMemoryError                          Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_parquet('cic-collection.parquet')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parquet.py:503, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     456 """
#     457 Load a parquet object from the file path, returning a DataFrame.
#     458
#    (...)
#     499 DataFrame
#     500 """
#     501 impl = get_engine(engine)
# --> 503 return impl.read(
#     504     path,
#     505     columns=columns,
#     506     storage_options=storage_options,
#     507     use_nullable_dtypes=use_nullable_dtypes,
#     508     **kwargs,
#     509 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parquet.py:251, in PyArrowImpl.read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
# ...

# %%
import pyarrow.parquet as pq

table = pq.ParquetFile('cic-collection.parquet')
print(table.schema.names)
# Out:
# ['Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Fwd Packets Length Total', 'Bwd Packets Length Total', 'Fwd Packet Length Max', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Packet Length Max', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'SYN Flag Count', 'URG Flag Count', 'Avg Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size', 'Subflow Fwd Packets', 'Subflow Fwd Bytes', 'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init Fwd Win Bytes', 'Init Bwd Win Bytes', 'Fwd Act Data Packets', 'Fwd Seg Size Min', 'Active 
# ...

# %%
import dask.dataframe as dd

df = dd.read_parquet('cic-collection.parquet')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ArrowMemoryError                          Traceback (most recent call last)
# Cell In[4], line 4
#       1 import dask.dataframe as dd
#       3 df = dd.read_parquet('cic-collection.parquet')
# ----> 4 df.head()
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\core.py:1540, in _Frame.head(self, n, npartitions, compute)
#    1538 # No need to warn if we're already looking at all partitions
#    1539 safe = npartitions != self.npartitions
# -> 1540 return self._head(n=n, npartitions=npartitions, compute=compute, safe=safe)
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\core.py:1574, in _Frame._head(self, n, npartitions, compute, safe)
#    1569 result = new_dd_object(
#    1570     graph, name, self._meta, [self.divisions[0], self.divisions[npartitions]]
#    1571 )
#    1573 if compute:
# -> 1574     result = result.compute()
#    1575 return result
#
# ...

# %%
import pyarrow.parquet as pq

parquet_file = pq.ParquetFile('cic-collection.parquet')

for i in range(parquet_file.num_row_groups):
    chunk = parquet_file.read_row_group(i).to_pandas()
    print(f"Chunk {i+1} shape:", chunk.shape)
    # Process each chunk here
# Out:
# ---------------------------------------------------------------------------
# ArrowMemoryError                          Traceback (most recent call last)
# Cell In[5], line 6
#       3 parquet_file = pq.ParquetFile('cic-collection.parquet')
#       5 for i in range(parquet_file.num_row_groups):
# ----> 6     chunk = parquet_file.read_row_group(i).to_pandas()
#       7     print(f"Chunk {i+1} shape:", chunk.shape)
#
# File ~\anaconda3\Lib\site-packages\pyarrow\array.pxi:884, in pyarrow.lib._PandasConvertible.to_pandas()
#
# File ~\anaconda3\Lib\site-packages\pyarrow\table.pxi:4192, in pyarrow.lib.Table._to_pandas()
#
# File ~\anaconda3\Lib\site-packages\pyarrow\pandas_compat.py:776, in table_to_dataframe(options, table, categories, ignore_metadata, types_mapper)
#     774 _check_data_column_metadata_consistency(all_columns)
#     775 columns = _deserialize_column_index(table, all_columns, column_indexes)
# ...
